# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
df_default = pd.read_csv("C:\\Users\\avikk\\OneDrive\\Desktop\\walker2d-demo\\plots\\learning_curve_default.csv")
df_custom = pd.read_csv("C:\\Users\\avikk\\OneDrive\\Desktop\\walker2d-demo\\plots\\learning_curve_custom.csv")

def plot_reward_data(df):
    # Convert the 'Value' column to numeric, coercing errors to NaN
    df['Value'] = pd.to_numeric(df['Value'], errors='coerce')

    # Drop rows with NaN values in the 'Value' column
    df = df.dropna(subset=['Value'])

    # Plot the data using seaborn
    plt.figure(figsize=(10, 6))
    sns.lineplot(x='Step', y='Value', data=df, label='Rollout Episode Reward Mean')
    plt.title('Rollout Episode Reward Mean Over Steps')
    plt.xlabel('Step')
    plt.ylabel('Rollout Episode Reward Mean')
    plt.legend()
    plt.show()

# %%
plot_reward_data(df_default)

# %%
plot_reward_data(df_custom)
